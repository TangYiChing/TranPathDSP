# %%
# %run ./explain_everolimus_prediction.py -h
# Out:
# usage: explain_everolimus_prediction.py [-h] -pred PRED_PATH -shap SHAP_PATH [-enrich ENRICH_PATH] [-info INFO_PATH]
#                                         [-drug DRUG_STR] [-top TOP_INT] -o OUTPUT_PATH
#
# Compare contributing pathway for TP and TN based on feature importance
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -pred PRED_PATH, --pred_path PRED_PATH
#                         path to prediction file (i.e., All.Prediction.txt)
#   -shap SHAP_PATH, --shap_path SHAP_PATH
#                         path to shapley values file (i.e., All.SHAP.txt)
#   -enrich ENRICH_PATH, --enrich_path ENRICH_PATH
#                         path to pathway enrichment file (.CHEM-DGNet-EXP.pkl)
#   -info INFO_PATH, --info_path INFO_PATH
#                         path to sample information file (i.e., .SampleInfo.txt)
#   -drug DRUG_STR, --drug_str DRUG_STR
#                         string representing drug name in uppercase, default=EVEROLIMUS
# ...

# %%
# %run ./explain_everolimus_prediction.py -pred ./InVivo_Binary/InVivo_Binary.PID_REACTOME.All.Prediction.txt -shap ./InVivo_Binary/InVivo_Binary.PID_REACTOME.All.SHAP.txt -enrich ./InVivo_Binary/InVivo_Binary.CHEM-DGNet-EXP.pkl -info ./InVivo_Binary/InVivo_Binary.SampleInfo.txt -drug EVEROLIMUS -top 10 -o EVEROLIMUS
# Out:
# Drug=EVEROLIMUS | #Cancer types=1
# ['BRCA']
# Confusion matrix=
# Predicted response   1   0
# Actual response
# 1                   49   3
# 0                   10  26
# Drug=EVEROLIMUS | #TP=49 | #TN=26
# Top10 contributing pathways
# R only=4 | NR only=4 | R & NR=6
# Mann-Witney U test for enrichment differences
#                                               Pathway      Set  \
# 12                    EXP_REACTOME_INFECTIOUS_DISEASE   R & NR
# 4   EXP_REACTOME_ANTI_INFLAMMATORY_RESPONSE_FAVOUR...  NR only
# 8   EXP_REACTOME_ADORA2B_MEDIATED_ANTI_INFLAMMATOR...   R & NR
# 2             EXP_REACTOME_VESICLE_MEDIATED_TRANSPORT   R only
# 10  EXP_REACTOME_DEGRADATION_OF_THE_EXTRACELLULAR_...   R & NR
# 0    EXP_REACTOME_CHEMOKINE_RECEPTORS_BIND_CHEMOKINES   R only
# 9          EXP_REACTOME_CLATHRIN_MEDIATED_ENDOCYTOSIS   R & NR
# 13                    EXP_REACTOME_SIGNALING_BY_NOTCH   R & NR
# 11     EXP_REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION   R & NR
# ...
