# %%
# %run ./compare_performance_transfer_notransfer.py -h
# Out:
# usage: compare_performance_transfer_notransfer.py [-h] [-transfer TRANSFER_PATH [TRANSFER_PATH ...]]
#                                                   [-notransfer NOTRANSFER_PATH [NOTRANSFER_PATH ...]] -task
#                                                   {regression,classification} [-feature FEATURE_STR [FEATURE_STR ...]]
#                                                   -o OUTPUT_PATH
#
# Compare performance difference in two groups
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -transfer TRANSFER_PATH [TRANSFER_PATH ...], --transfer_path TRANSFER_PATH [TRANSFER_PATH ...]
#                         path to performance file (i.e., .Performance.txt)
#   -notransfer NOTRANSFER_PATH [NOTRANSFER_PATH ...], --notransfer_path NOTRANSFER_PATH [NOTRANSFER_PATH ...]
#                         path to performance file (i.e., ., Performance.txt
#   -task {regression,classification}, --task_str {regression,classification}
# ...

# %% [markdown]
# ## plot Figure 2A

# %%
# %run ./compare_performance_transfer_notransfer.py -transfer ./Transfer/Tumors/InVivo_Binary.PID.Performance.txt ./Transfer/Tumors/InVivo_Binary.REACTOME.Performance.txt ./Transfer/Tumors/InVivo_Binary.PID_REACTOME.Performance.txt -notransfer ./Notransfer/Tumors/InVivo_Binary.PID.Performance.txt ./Notransfer/Tumors/InVivo_Binary.REACTOME.Performance.txt ./Notransfer/Tumors/InVivo_Binary.PID_REACTOME.Performance.txt -f PID REACTOME PID+REACTOME -task classification -o Tumors
# Out:
# Comparing performance between transfer and no transfer in order=['PID', 'REACTOME', 'PID+REACTOME']
# Feature=PID | Transfer vs. Notransfer=3.3 (pvalue=0.0010778335841932208)
# Feature=REACTOME | Transfer vs. Notransfer=2.7 (pvalue=0.007632881787792299)
# Feature=PID+REACTOME | Transfer vs. Notransfer=3.1 (pvalue=0.002243495063082974)
# find boxplot at Tumors.ComparePerformance.TransferNotransfer.BOXPLOT.png

# %% [markdown]
# ## plot Figure 2B

# %%
# %run ./compare_performance_transfer_notransfer.py -transfer ./Transfer/PDX_D/ExVivo_Binary.PID.Performance.txt ./Transfer/PDX_D/ExVivo_Binary.REACTOME.Performance.txt ./Transfer/PDX_D/ExVivo_Binary.PID_REACTOME.Performance.txt -notransfer ./Notransfer/PDX_D/ExVivo_Binary.PID.Performance.txt ./Notransfer/PDX_D/ExVivo_Binary.REACTOME.Performance.txt ./Notransfer/PDX_D/ExVivo_Binary.PID_REACTOME.Performance.txt -f PID REACTOME PID+REACTOME -task classification -o PDX-D
# Out:
# Comparing performance between transfer and no transfer in order=['PID', 'REACTOME', 'PID+REACTOME']
# Feature=PID | Transfer vs. Notransfer=1.1 (pvalue=0.2523052121646835)
# Feature=REACTOME | Transfer vs. Notransfer=3.2 (pvalue=0.001154141900605938)
# Feature=PID+REACTOME | Transfer vs. Notransfer=-0.4 (pvalue=0.65540543793669)
# find boxplot at PDX-D.ComparePerformance.TransferNotransfer.BOXPLOT.png

# %% [markdown]
# ## plot Figure 2C

# %%
# %run ./compare_performance_transfer_notransfer.py -transfer ./Transfer/PDX_C/ExVivo_Continuous.PID.Performance.txt ./Transfer/PDX_C/ExVivo_Continuous.REACTOME.Performance.txt ./Transfer/PDX_C/ExVivo_Continuous.PID_REACTOME.Performance.txt -notransfer ./Notransfer/PDX_C/ExVivo_Continuous.PID.Performance.txt ./Notransfer/PDX_C/ExVivo_Continuous.REACTOME.Performance.txt ./Notransfer/PDX_C/ExVivo_Continuous.PID_REACTOME.Performance.txt -f PID REACTOME PID+REACTOME -task regression -o PDX-C
# Out:
# Comparing performance between transfer and no transfer in order=['PID', 'REACTOME', 'PID+REACTOME']
# Feature=PID | Transfer vs. Notransfer=-6.0 (pvalue=2.153563196682599e-09)
# Feature=REACTOME | Transfer vs. Notransfer=-1.9 (pvalue=0.05852058232738107)
# Feature=PID+REACTOME | Transfer vs. Notransfer=1.1 (pvalue=0.2645660392392569)
# find boxplot at PDX-C.ComparePerformance.TransferNotransfer.BOXPLOT.png
