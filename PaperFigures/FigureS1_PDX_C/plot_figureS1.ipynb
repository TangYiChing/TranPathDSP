# %% [markdown]
# ## scatter plot

# %%
# %run ./retrieve_GDSC_from_Powell.py
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# #drug-cell pairs=4658
#                          GDSC AUC    AUC_FA
# Therapy        Sample
# 5-FLUOROURACIL A375      0.917748  0.065076
#                A427      0.892071  0.067536
#                A549      0.768499  0.203022
#                AGS       0.919674  0.111671
#                AN3-CA    0.976891  0.028767
# ...                           ...       ...
# ZM447439       MRK-nu-1  0.856916  0.358545
#                OCUB-M    0.832950  0.310599
#                T47D      0.948422  0.087584
#                UACC-893  0.953151  0.043192
#                ZR-75-30  0.924716  0.068933
#
# [4658 rows x 2 columns]

# %% [markdown]
# ## boxplot

# %%
# %run ./compare_performance_transfer_notransfer.py -h
# Out:
# usage: compare_performance_transfer_notransfer.py [-h] [-transfer TRANSFER_PATH [TRANSFER_PATH ...]]
#                                                   [-notransfer NOTRANSFER_PATH [NOTRANSFER_PATH ...]] -task
#                                                   {regression,classification} [-feature FEATURE_STR [FEATURE_STR ...]]
#                                                   -o OUTPUT_PATH
#
# Compare performance difference in two groups
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -transfer TRANSFER_PATH [TRANSFER_PATH ...], --transfer_path TRANSFER_PATH [TRANSFER_PATH ...]
#                         path to performance file (i.e., .Performance.txt)
#   -notransfer NOTRANSFER_PATH [NOTRANSFER_PATH ...], --notransfer_path NOTRANSFER_PATH [NOTRANSFER_PATH ...]
#                         path to performance file (i.e., ., Performance.txt
#   -task {regression,classification}, --task_str {regression,classification}
# ...

# %%
# %run ./compare_performance_transfer_notransfer.py -transfer ./GDSC_AUC/Transfer/ExVivo_Continuous.PID.Performance.txt ./GDSC_AUC/Transfer/ExVivo_Continuous.REACTOME.Performance.txt ./GDSC_AUC/Transfer/ExVivo_Continuous.PID_REACTOME.Performance.txt -notransfer ./GDSC_AUC/Notransfer/ExVivo_Continuous.PID.Performance.txt ./GDSC_AUC/Notransfer/ExVivo_Continuous.REACTOME.Performance.txt ./GDSC_AUC/Notransfer/ExVivo_Continuous.PID_REACTOME.Performance.txt -feature PID REACTOME PID+REACTOME -task regression -o GDSC_AUC
# Out:
# Comparing performance between transfer and no transfer in order=['PID', 'REACTOME', 'PID+REACTOME']
# Feature=PID | Transfer vs. Notransfer=-2.2 (pvalue=0.02904902216194057)
# Feature=REACTOME | Transfer vs. Notransfer=-0.0 (pvalue=0.9613120861932752)
# Feature=PID+REACTOME | Transfer vs. Notransfer=1.3 (pvalue=0.1902999240389237)
# find boxplot at GDSC_AUC.ComparePerformance.TransferNotransfer.BOXPLOT.png

# %%
# %run ./compare_performance_transfer_notransfer.py -transfer ./adjusted_AUC/Transfer/ExVivo_Continuous.PID.Performance.txt ./adjusted_AUC/Transfer/ExVivo_Continuous.REACTOME.Performance.txt ./adjusted_AUC/Transfer/ExVivo_Continuous.PID_REACTOME.Performance.txt -notransfer ./adjusted_AUC/Notransfer/ExVivo_Continuous.PID.Performance.txt ./adjusted_AUC/Notransfer/ExVivo_Continuous.REACTOME.Performance.txt ./adjusted_AUC/Notransfer/ExVivo_Continuous.PID_REACTOME.Performance.txt -feature PID REACTOME PID+REACTOME -task regression -o adjusted_AUC
# Out:
# Comparing performance between transfer and no transfer in order=['PID', 'REACTOME', 'PID+REACTOME']
# Feature=PID | Transfer vs. Notransfer=-6.0 (pvalue=2.153563196682599e-09)
# Feature=REACTOME | Transfer vs. Notransfer=-1.9 (pvalue=0.05852058232738107)
# Feature=PID+REACTOME | Transfer vs. Notransfer=1.1 (pvalue=0.2645660392392569)
# find boxplot at adjusted_AUC.ComparePerformance.TransferNotransfer.BOXPLOT.png
