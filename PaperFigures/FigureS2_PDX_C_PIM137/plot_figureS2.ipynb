# %%
# %run ./explain_pim137_prediction.py -h
# Out:
# usage: explain_pim137_prediction.py [-h] -pred PRED_PATH -shap SHAP_PATH [-enrich ENRICH_PATH] [-info INFO_PATH]
#                                     [-sample SAMPLE_STR] [-top TOP_INT] -o OUTPUT_PATH
#
# Explain PIM137 prediction
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -pred PRED_PATH, --pred_path PRED_PATH
#                         path to prediction file (i.e., All.Prediction.txt)
#   -shap SHAP_PATH, --shap_path SHAP_PATH
#                         path to shapley values file (i.e., All.SHAP.txt)
#   -enrich ENRICH_PATH, --enrich_path ENRICH_PATH
#                         path to pathway enrichment file (.CHEM-DGNet-EXP.pkl)
#   -info INFO_PATH, --info_path INFO_PATH
#                         path to sample information file (i.e., .SampleInfo.txt)
#   -sample SAMPLE_STR, --sample_str SAMPLE_STR
#                         string representing sample name in uppercase, e.g. PIM137
#   -top TOP_INT, --top_int TOP_INT
#                         integer representing top N features, default=10
#   -o OUTPUT_PATH, --output_path OUTPUT_PATH
#                         output prefix

# %%
# %run ./explain_pim137_prediction.py -pred ./ExVivo_Continuous/ExVivo_Continuous.PID.All.Prediction.txt -shap ./ExVivo_Continuous/ExVivo_Continuous.PID.All.SHAP.txt -enrich ./ExVivo_Continuous/ExVivo_Continuous.CHEM-DGNet-EXP.pkl -info ./ExVivo_Continuous/ExVivo_Continuous.SampleInfo.txt -o PIM137
# Out:
# Sample=PIM137 | #Drug=340
# Sample=PIM137 | select by top/bottom n=68 | #TP=68 | #TN=68
# Top10 contributing pathways
# TP only=4 | TN only=4 | TP&TN=6
# Mann-Witney U test for enrichment differences
#                            Pathway      Set  Mann-Witney U Test statistic  \
# 2   DGNet_PID_HDAC_CLASSII_PATHWAY  TP only                          3.53
# 11                   CHEM_mBit_175  TP & TN                          2.42
# 1                     CHEM_mBit_29  TP only                          1.92
# 6                     CHEM_mBit_48  TN only                         -1.81
# 7                     CHEM_mBit_66  TN only                         -1.67
# 8                    CHEM_mBit_123  TP & TN                          1.32
# 10                   CHEM_mBit_168  TP & TN                          1.07
# 9                    CHEM_mBit_166  TP & TN                          0.61
# 13                   CHEM_mBit_201  TP & TN                          0.61
# 0                    CHEM_mBit_142  TP only                          0.58
# 4                    CHEM_mBit_121  TN only                         -0.33
# 5                     CHEM_mBit_30  TN only                         -0.31
# 12                   CHEM_mBit_183  TP & TN                          0.28
# 3          DGNet_PID_IL12_2PATHWAY  TP only                         -0.14
#
#      P-value       FDR
# 2   4.21e-04  5.90e-03
# 11  1.55e-02  1.08e-01
# 1   5.44e-02  2.47e-01
# 6   7.04e-02  2.47e-01
# 7   9.49e-02  2.66e-01
# 8   1.87e-01  4.37e-01
# 10  2.86e-01  5.73e-01
# 9   5.40e-01  7.91e-01
# 13  5.40e-01  7.91e-01
# 0   5.65e-01  7.91e-01
# 4   7.38e-01  8.41e-01
# 5   7.59e-01  8.41e-01
# 12  7.81e-01  8.41e-01
# 3   8.91e-01  8.91e-01
# #significant differentially expressed top contributing pathways=
#                           Pathway      Set  Mann-Witney U Test statistic  \
# 2  DGNet_PID_HDAC_CLASSII_PATHWAY  TP only                          3.53
#
#     P-value       FDR
# 2  4.21e-04  5.90e-03
#                  Therapy  Sample                         Pathway  \
# 0             BORTEZOMIB  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 1                MLN2238  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 2   SEPANTRONIUM BROMIDE  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 3             TRIPTOLIDE  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 4                 YM-155  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# ..                   ...     ...                             ...
# 69            LY-2157299  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 70             DASATINIB  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 71                TPCA-1  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 72                AT7867  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
# 73           MOMELOTINIB  PIM137  DGNet_PID_HDAC_CLASSII_PATHWAY
#
#     Enrichment Score                Group      Set
# 0               0.42     PIM137-Responder  TP only
# 1               0.11     PIM137-Responder  TP only
# 2               0.23     PIM137-Responder  TP only
# 3               0.20     PIM137-Responder  TP only
# 4               0.23     PIM137-Responder  TP only
# ..               ...                  ...      ...
# 69              0.08  PIM137-NonResponder  TP only
# 70              0.98  PIM137-NonResponder  TP only
# 71              0.10  PIM137-NonResponder  TP only
# 72              0.36  PIM137-NonResponder  TP only
# 73              0.30  PIM137-NonResponder  TP only
#
# [142 rows x 6 columns]
# WARNING: skipping catplot due to #SigDEG=1
# pathway=DGNet_PID_HDAC_CLASSII_PATHWAY | PCC=0.12 ] p-value=3.6276564640259594e-16
# pathway=DGNet_PID_IL12_2PATHWAY | PCC=0.09 ] p-value=4.331155243868099e-10
