# %%
# %run ./compare_GDSC_nonGDSC.py -h
# Out:
# usage: compare_GDSC_nonGDSC.py [-h] [-cell CELL_PATH] [-transfer TRANSFER_PATH] [-notransfer NOTRANSFER_PATH] -task
#                                {regression,classification} [-groupby {Drug,Cancer}] [-data DATA_STR] -o OUTPUT_PATH
#
# Compare performance difference in two groups
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -cell CELL_PATH, --cell_path CELL_PATH
#                         path to GDSC sample information file (i.e., .SampleInfo.txt)
#   -transfer TRANSFER_PATH, --transfer_path TRANSFER_PATH
#                         path to prediction file (i.e., ., GroupMean.txt
#   -notransfer NOTRANSFER_PATH, --notransfer_path NOTRANSFER_PATH
#                         path to prediction file (i.e., ., GroupMean.txt
#   -task {regression,classification}, --task_str {regression,classification}
#                         string representing job task
#   -groupby {Drug,Cancer}, --groupby_str {Drug,Cancer}
# ...

# %% [markdown]
# ## plot Figure 3A

# %%
# %run ./compare_GDSC_nonGDSC.py -cell ./Tumors/InVitro_Continuous.SampleInfo.txt -transfer ./Tumors/Transfer/InVivo_Binary.PID_REACTOME.Performance.Drug.GroupMean.txt -notransfer ./Tumors/Notransfer/InVivo_Binary.PID_REACTOME.NoTransfer.Performance.Drug.GroupMean.txt -groupby Drug -task classification -data Tumors -o Tumors
# Out:
#                         No transfer  Transfer
# Name
# AFATINIB                   0.376923  0.574359
# ANASTROZOLE                0.648065  0.607419
# CISPLATIN                  0.314286  0.526190
# DABRAFENIB                 0.340000  0.410667
# EVEROLIMUS                 0.824038  0.896688
# EXEMESTANE                 0.450000  0.583333
# FLUOROURACIL               0.175000  0.333333
# GEMCITABINE                0.320000  0.514286
# LETROZOLE                  0.528676  0.613235
# SORAFENIB                  0.885512  0.887943
# TAMOXIFEN                  0.735185  0.762963
# TEMOZOLOMIDE               0.316667  0.833333
# TRASTUZUMAB DERUXTECAN     0.501984  0.619048
# VEMURAFENIB                0.333333  1.000000
# find file at Tumors.Performance.Drug.GDSCvs.nonGDSC.txt

# %%
# %run ./compare_GDSC_nonGDSC.py -cell ./Tumors/InVitro_Continuous.SampleInfo.txt -transfer ./Tumors/Transfer/InVivo_Binary.PID_REACTOME.Performance.Cancer.GroupMean.txt -notransfer ./Tumors/Notransfer/InVivo_Binary.PID_REACTOME.NoTransfer.Performance.Cancer.GroupMean.txt -groupby Cancer -task classification -data Tumors -o Tumors
# Out:
#        No transfer  Transfer
# Name
# BLCA      0.300000  1.000000
# BRCA      0.725930  0.786793
# CESC      0.311111  0.422222
# HNSCC     0.506667  0.652222
# LGG       0.500000  0.900000
# LIHC      0.881438  0.887269
# LUAD           NaN       NaN
# PAAD      0.155556  0.222222
# SKCM      0.396923  0.543846
# STAD      0.188889  0.222222
# UCS       0.400000  0.600000
# find file at Tumors.Performance.Cancer.GDSCvs.nonGDSC.txt

# %% [markdown]
# ## plot Figure 3B

# %%
# %run ./compare_GDSC_nonGDSC.py -cell ./PDX_D/InVitro_Continuous.SampleInfo.txt -transfer ./PDX_D/Transfer/ExVivo_Binary.PID.Performance.Drug.GroupMean.txt -notransfer ./PDX_D/Notransfer/ExVivo_Binary.PID.NoTransfer.Performance.Drug.GroupMean.txt -groupby Drug -task classification -data PDX-D -o PDX_D
# Out:
#              No transfer  Transfer
# Name
# BGJ398          0.400000  0.525926
# BINIMETINIB     0.725391  0.708984
# BKM120          0.478125  0.478125
# BYL719          0.725000  0.729167
# CGM097          0.829630  0.807407
# DACARBAZINE     0.583333  0.566667
# ERLOTINIB       0.703704  0.674074
# GEMCITABINE     0.447619  0.531973
# HDM201          0.466667  0.616667
# LEE011          0.712963  0.657407
# PACLITAXEL      0.765333  0.802667
# TRAMETINIB      0.333333  0.585185
# find file at PDX_D.Performance.Drug.GDSCvs.nonGDSC.txt

# %%
# %run ./compare_GDSC_nonGDSC.py -cell ./PDX_D/InVitro_Continuous.SampleInfo.txt -transfer ./PDX_D/Transfer/ExVivo_Binary.PID.Performance.Cancer.GroupMean.txt -notransfer ./PDX_D/Notransfer/ExVivo_Binary.PID.NoTransfer.Performance.Cancer.GroupMean.txt -groupby Cancer -task classification -data PDX-D -o PDX_D
# Out:
#        No transfer  Transfer
# Name
# BRCA      0.608730  0.633069
# CRC       0.384848  0.436364
# NSCLC     0.529297  0.586719
# PDAC      0.553592  0.644795
# SKCM      0.717391  0.721739
# find file at PDX_D.Performance.Cancer.GDSCvs.nonGDSC.txt

# %% [markdown]
# ## plot Figure 3C

# %%
# %run ./compare_GDSC_nonGDSC.py -cell ./PDX_D/InVitro_Continuous.SampleInfo.txt -transfer ./PDX_C/Transfer/ExVivo_Continuous.PID.Performance.Drug.GroupMean.txt -notransfer ./PDX_C/Notransfer/ExVivo_Continuous.PID.Performance.Drug.GroupMean.txt -groupby Drug -task regression -data PDX-C -o PDX_C
# Out:
#                                 No transfer  Transfer
# Name
# (R)-(+)-Etomoxir (sodium salt)     0.043897  0.053816
# 968                                0.111904  0.116841
# A-804598                           0.069930  0.045825
# ABIRATERONE                        0.046527  0.037831
# ABT-199                            0.079648  0.068432
# ...                                     ...       ...
# XL765                              0.053955  0.052988
# YK 4-279                           0.036726  0.040614
# YM-155                             0.128446  0.111391
# ZEBULARINE                         0.094131  0.054632
# ZSTK474                            0.079128  0.069709
#
# [340 rows x 2 columns]
# find file at PDX_C.Performance.Drug.GDSCvs.nonGDSC.txt

# %%
# %run ./compare_GDSC_nonGDSC.py -cell ./PDX_D/InVitro_Continuous.SampleInfo.txt -transfer ./PDX_C/Transfer/ExVivo_Continuous.PID.Performance.Cancer.GroupMean.txt -notransfer ./PDX_C/Notransfer/ExVivo_Continuous.PID.Performance.Cancer.GroupMean.txt -groupby Cancer -task regression -data PDX-C -o PDX_C
# Out:
#       No transfer  Transfer
# Name
# BRCA     0.118523   0.10326
# find file at PDX_C.Performance.Cancer.GDSCvs.nonGDSC.txt
